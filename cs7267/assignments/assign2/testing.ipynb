# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("wdbc.data.mb.csv", header=None)

# %%
df.describe()
# Out:
#                0           1           2            3           4   \
# count  613.000000  613.000000  613.000000   613.000000  613.000000
# mean    14.192026   19.391240   92.412969   661.607830    0.096297
# std      3.563524    4.352253   24.563996   359.449204    0.013984
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.740000   16.320000   75.460000   422.900000    0.086050
# 50%     13.440000   18.900000   87.020000   556.700000    0.095860
# 75%     16.020000   21.880000  104.700000   793.200000    0.105100
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#                5           6           7           8           9   ...  \
# count  613.000000  613.000000  613.000000  613.000000  613.000000  ...
# mean     0.104640    0.089480    0.049305    0.181179    0.062682  ...
# std      0.052168    0.079377    0.038684    0.027249    0.006988  ...
# min      0.019380    0.000000    0.000000    0.106000    0.049960  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       613 non-null    float64
#  1   1       613 non-null    float64
#  2   2       613 non-null    float64
#  3   3       613 non-null    float64
#  4   4       613 non-null    float64
#  5   5       613 non-null    float64
#  6   6       613 non-null    float64
#  7   7       613 non-null    float64
#  8   8       613 non-null    float64
#  9   9       613 non-null    float64
#  10  10      613 non-null    float64
#  11  11      613 non-null    float64
#  12  12      613 non-null    float64
#  13  13      613 non-null    float64
#  14  14      613 non-null    float64
#  15  15      613 non-null    float64
#  16  16      613 non-null    float64
#  17  17      613 non-null    float64
#  18  18      613 non-null    float64
#  19  19      613 non-null    float64
# ...

# %%
df.head()
# Out:
#        0      1      2      3        4        5        6         7       8   \
# 0   8.196  16.84  51.71  201.9  0.08600  0.05943  0.01588  0.005917  0.1769
# 1  13.170  18.66  85.98  534.6  0.11580  0.12310  0.12260  0.073400  0.2128
# 2  12.050  14.63  78.04  449.3  0.10310  0.09092  0.06592  0.027490  0.1675
# 3  13.490  22.30  86.91  561.0  0.08752  0.07698  0.04751  0.033840  0.1809
# 4  11.760  21.60  74.72  427.9  0.08637  0.04966  0.01657  0.011150  0.1495
#
#         9   ...     21      22     23      24       25       26       27  \
# 0  0.06503  ...  21.96   57.26  242.2  0.1297  0.13570  0.06880  0.02564
# 1  0.06777  ...  27.95  102.80  759.4  0.1786  0.41660  0.50060  0.20880
# 2  0.06043  ...  20.70   89.88  582.6  0.1494  0.21560  0.30500  0.06548
# 3  0.05718  ...  31.82   99.00  698.8  0.1162  0.17110  0.22820  0.12820
# 4  0.05888  ...  25.72   82.98  516.5  0.1085  0.08615  0.05523  0.03715
#
#        28       29  30
# 0  0.3105  0.07409  -1
# ...

# %%
print(df.shape)
print(df.isnull().values.any())
# Out:
# (613, 31)
# False

# %%
print((df.mean() < 0.5).sum()) # calculate mean for each column
# Out:
# 20

# %%
print((df.mean() > 100).sum())
# Out:
# 3

# %%
print((df.mean() > 50).sum())
# Out:
# 4

# %%
print((df.mean() > 500).sum())
# Out:
# 2

# %%
print((df.mean() > 10).sum())
# Out:
# 9

# %%
print((df.mean() < 0.1).sum())
# Out:
# 12

# %%
print((df.mean() < 0.05).sum())
# Out:
# 8

# %%
print((df.mean() < 0.01).sum())
# Out:
# 3

# %%
np.mean(df.to_numpy())
# Out:
# 60.472273710287844

# %%
X_d = df.iloc[:, :30].astype(float) 
print(X_d.shape)
# Out:
# (613, 30)
