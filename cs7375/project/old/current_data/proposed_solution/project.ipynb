# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
#Initially just geographic and demographic datasets
df_demo = pd.read_csv('nchs_cleaned.csv',encoding='latin-1') #columns State, County, LifeExpectancyStandardError, LifeExpectancy  
df_geo = pd.read_csv('life_expectancy_by_county_data.csv',encoding='latin-1') #year, race, sex, AgeAdjustedDeathRate, LifeExpectancy

# %%
#add columns that are in df_geo to df_demo
df_demo[["State", "County", "LifeExpectancyStandardError"]] = None

# %%
df = pd.concat([df_geo, df_demo], ignore_index=True)
# Out:
# /tmp/ipykernel_69446/1267531392.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df_geo, df_demo], ignore_index=True)

# %%
print(df.info())
print(df.shape)
print(df.describe().T)
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4215 entries, 0 to 4214
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State                        3144 non-null   object
#  1   County                       3144 non-null   object
#  2   LifeExpectancy               4215 non-null   float64
#  3   LifeExpectancyStandardError  3144 non-null   float64
#  4   Year                         1071 non-null   float64
#  5   Race                         1071 non-null   object
#  6   Sex                          1071 non-null   object
#  7   AgeAdjustedDeathRate         1071 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 263.6+ KB
# None
# (4215, 8)
#                               count         mean         std        min  \
# LifeExpectancy               4215.0    74.392776    8.560774    29.1000
# ...

# %%
print(df.isnull().sum().sum())
# Out:
# 15789
